# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import sys
sys.path.append('../src')
from data_prep import *

# %matplotlib inline

# %% [markdown]
# ## Construct Master Dataframe

# %%
cs_1 = load_data('../data/01-population_and_households.csv')
cs_2 = load_data('..//data/02-natural_environment.csv')
cs_5 = load_data('../data/05-education.csv')
cs_6 = load_data('../data/06-labour.csv')

# %%
cs_1.head().T
# Out:
#                                                               0  \
# city_code                                                  1100
# City                                                Sapporo-shi
# Total population (Both sexes)[person]                 1,952,356
# Total population (Male)[person]                         910,614
# Total population (Female)[person]                     1,041,742
# Japanese population (Both sexes)[person]              1,937,785
# Japanese population (Male)[person]                      903,535
# Japanese population (Female)[person]                  1,034,250
# Median age[age]                                            46.4
# Ratio of never married persons (population 15 y...     29.83508
# Foreigners (Total)[person]                                8,820
# Number of in-migrants from other municipalities...      120,932
# Number of out-migrants to other municipalities[...      112,759
# Number of in-migrants from other prefectures (A...          ***
# ...

# %%
cs_2.head().T
# Out:
#                                                               0  \
# city_code                                                  1100
# City                                                Sapporo-shi
# Total land area (Incl. the northern territories...       112126
# Inhabitable area[ha]                                      44036
# Main lakes and marshes area[ha]                               0
# Woodland area[ha]                                         68228
# Forest area[ha]                                           67690
# Area of grass fields other than forest[ha]                  538
# Prefecture                                             Hokkaido
#
#                                                                       1  \
# city_code                                                          1101
# City                                                Sapporo-shi Chuo-ku
# Total land area (Incl. the northern territories...                 4642
# ...

# %%
cs_5.head().T
# Out:
#                                                               0  \
# city_code                                                  1100
# City                                                Sapporo-shi
# Number of kindergartens[number of kindergartens]            127
# Number of Kindergarten students[person]                   22645
# Number of elementary schools[number of schools]             206
# Number of elementary school teachers[person]               4811
# Elementary school students[person]                        89770
# Number of lower secondary schools[number of sch...          108
# Number of lower secondary school teachers[person]          3027
# Lower secondary school students[person]                   46814
# Number of upper secondary schools[number of sch...           53
# Upper secondary school students[person]                   45616
# Population by last school completed (Graduates)...          ***
# Population by last school completed (Elementary...          ***
# ...

# %%
cs_6.head().T
# Out:
#                                                               0  \
# city_code                                                  1100
# City                                                Sapporo-shi
# (Population census) Population in labour force[...       892932
# (Population census) Employed persons[person]             844313
# (Population census) Employed persons, mostly wo...       697836
# (Population census) Employed persons, worked be...       110809
# (Population census) Employed persons, working b...        19156
# (Population census) Employed persons, Absent fr...        16512
# (Population census) Unemployed persons[person]            48619
# (Population census) Unemployed persons (Male)[p...        29114
# (Population census) Unemployed persons (Female)...        19505
# (Population census) Population not in labour fo...       651052
# (Population census) Population not in labour fo...       251107
# (Population census) Population not in labour fo...        93668
# ...

# %%
df = create_master_dataframe('../data')
df.head().T
# Out:
#                                                       0                    1  \
# city_code                                          1100                 1101
# City                                        Sapporo-shi  Sapporo-shi Chuo-ku
# Total population (Both sexes)[person]         1,952,356              237,627
# Total population (Male)[person]                 910,614              107,756
# Total population (Female)[person]             1,041,742              129,871
# ...                                                 ...                  ...
# Inhabitable area[ha]                              44036                 2683
# Main lakes and marshes area[ha]                       0                    0
# Woodland area[ha]                                 68228                 1957
# Forest area[ha]                                   67690                 1956
# Area of grass fields other than forest[ha]          538                    1
#
# ...

# %%
df.describe().T
# Out:
#                                                      count          mean  \
# city_code                                           1917.0  21238.153365
# Number of kindergartens[number of kindergartens]    1917.0      7.586854
# Number of Kindergarten students[person]             1917.0    968.767345
# Number of elementary schools[number of schools]     1917.0     12.790297
# Number of elementary school teachers[person]        1917.0    268.514345
# Elementary school students[person]                  1917.0   4329.885759
# Number of lower secondary schools[number of sch...  1917.0      6.591028
# Number of lower secondary school teachers[person]   1917.0    163.004695
# Lower secondary school students[person]             1917.0   2287.804382
# Number of upper secondary schools[number of sch...  1917.0      3.170579
# Upper secondary school students[person]             1917.0   2236.399061
# (Population census) Population in labour force[...  1917.0  41019.801774
# ...
